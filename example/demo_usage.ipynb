# %% [markdown]
# # Demonstration of the usage of vita-python utilities
# This notebook demonstrate three major usages:
# 1. Define area using numpy 3d array and save it as `.vtk` file for VItA vessel synthesis
# 2. Synthesize vessels based on docker containerized VItA
# 3. Voxelize the generated `vessel.vtp` file to produce the 3d numpy.ndarray
#
# For more information about the `VItA` and `vita docker container`,\
# Please check the `README.md` of this repo.

# %% [markdown]
# ## Install the package

# %%
## Install the package locally if the repo is cloned
# !pip install -e ..

## Install the package from git directly
# !pip install git+https://github.com/kevinh0718/vita_python_util.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///home/hkhuang3/Documents/m23s_general/KH230209_mice_vita/vita_python_util
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /home/hkhuang3/.local/lib/python3.10/site-packages (from vita_python_utils==0.1.0) (1.26.4)
# Requirement already satisfied: scipy in /home/hkhuang3/.local/lib/python3.10/site-packages (from vita_python_utils==0.1.0) (1.15.0)
# Requirement already satisfied: pyvista in /home/hkhuang3/.local/lib/python3.10/site-packages (from vita_python_utils==0.1.0) (0.38.1)
# Requirement already satisfied: vtk in /home/hkhuang3/.local/lib/python3.10/site-packages (from vita_python_utils==0.1.0) (9.2.5)
# Requirement already satisfied: scikit-image in /home/hkhuang3/.local/lib/python3.10/site-packages (from vita_python_utils==0.1.0) (0.25.2)
# Requirement already satisfied: trimesh in /home/hkhuang3/.local/lib/python3.10/site-packages (from vita_python_utils==0.1.0) (4.7.4)
# Requirement already satisfied: meshio in /home/hkhuang3/.local/lib/python3.10/site-packages (from vita_python_utils==0.1.0) (5.3.5)
# Requirement already satisfied: rich in /home/hkhuang3/.local/lib/python3.10/site-packages (from meshio->vita_python_utils==0.1.0) (14.2.0)
# Requirement already satisfied: imageio in /home/hkhuang3/.local/lib/python3.10/site-packages (from pyvista->vita_python_utils==0.1.0) (2.37.0)
# Requirement already satisfied: pillow in /home/hkhuang3/.local/lib/python3.10/site-packages (from pyvista->vita_python_utils==0.1.0) (10.1.0)
# Requirement already satisfied: pooch in /home/hkhuang3/.local/lib/python3.10/site-packages (from pyvista->vita_python_utils==0.1.0) (1.6.0)
# Requirement already satisfied: scooby>=0.5.1 in /home/hkhuang3/.local/lib/python3.10/site-packages (from pyvista->vita_python_utils==0.1.0) (0.7.1)
# Requirement already satisfied: networkx>=3.0 in /home/hkhuang3/.local/lib/python3.10/site-packages (from scikit-image->vita_python_utils==0.1.0) (3.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/hkhuang3/.local/lib/python3.10/site-packages (from scikit-image->vita_python_utils==0.1.0) (2023.1.23.1)
# Requirement already satisfied: packaging>=21 in /home/hkhuang3/.local/lib/python3.10/site-packages (from scikit-image->vita_python_utils==0.1.0) (24.0)
# Requirement already satisfied: lazy-loader>=0.4 in /home/hkhuang3/.local/lib/python3.10/site-packages (from scikit-image->vita_python_utils==0.1.0) (0.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /software/python-3.10.0/lib/python3.10/site-packages (from vtk->vita_python_utils==0.1.0) (3.5.0)
# Requirement already satisfied: cycler>=0.10 in /home/hkhuang3/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->vtk->vita_python_utils==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hkhuang3/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->vtk->vita_python_utils==0.1.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/hkhuang3/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->vtk->vita_python_utils==0.1.0) (1.4.9)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/hkhuang3/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->vtk->vita_python_utils==0.1.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/hkhuang3/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->vtk->vita_python_utils==0.1.0) (2.9.0.post0)
# Requirement already satisfied: setuptools-scm>=4 in /software/python-3.10.0/lib/python3.10/site-packages (from matplotlib>=2.0.0->vtk->vita_python_utils==0.1.0) (6.3.2)
# Requirement already satisfied: appdirs>=1.3.0 in /home/hkhuang3/.local/lib/python3.10/site-packages (from pooch->pyvista->vita_python_utils==0.1.0) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /home/hkhuang3/.local/lib/python3.10/site-packages (from pooch->pyvista->vita_python_utils==0.1.0) (2.31.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/hkhuang3/.local/lib/python3.10/site-packages (from rich->meshio->vita_python_utils==0.1.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/hkhuang3/.local/lib/python3.10/site-packages (from rich->meshio->vita_python_utils==0.1.0) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /home/hkhuang3/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->meshio->vita_python_utils==0.1.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/hkhuang3/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->vtk->vita_python_utils==0.1.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hkhuang3/.local/lib/python3.10/site-packages (from requests>=2.19.0->pooch->pyvista->vita_python_utils==0.1.0) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/hkhuang3/.local/lib/python3.10/site-packages (from requests>=2.19.0->pooch->pyvista->vita_python_utils==0.1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hkhuang3/.local/lib/python3.10/site-packages (from requests>=2.19.0->pooch->pyvista->vita_python_utils==0.1.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hkhuang3/.local/lib/python3.10/site-packages (from requests>=2.19.0->pooch->pyvista->vita_python_utils==0.1.0) (2022.12.7)
# Requirement already satisfied: setuptools in /home/hkhuang3/.local/lib/python3.10/site-packages (from setuptools-scm>=4->matplotlib>=2.0.0->vtk->vita_python_utils==0.1.0) (67.6.0)
# Requirement already satisfied: tomli>=1.0.0 in /software/python-3.10.0/lib/python3.10/site-packages (from setuptools-scm>=4->matplotlib>=2.0.0->vtk->vita_python_utils==0.1.0) (1.2.2)
# Building wheels for collected packages: vita_python_utils
#   Building editable for vita_python_utils (pyproject.toml) ... done
#   Created wheel for vita_python_utils: filename=vita_python_utils-0.1.0-0.editable-py3-none-any.whl size=1725 sha256=5dd4aeb312990aa33706b913a12f8aee661633ef5189204718fb446e3ff74fc4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-roowm5mk/wheels/fa/18/c7/339fa3d5eb741f1497807130ee461ca72db449f3cced41840d
# Successfully built vita_python_utils
# Installing collected packages: vita_python_utils
# Successfully installed vita_python_utils-0.1.0
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ##
